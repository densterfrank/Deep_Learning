# %%
# !nvidia-smi
# Out:
# Tue Jan 24 13:01:53 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P0    27W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
cd /content/drive/MyDrive/Projects/Retail_Shop
# Out:
# /content/drive/MyDrive/Projects/Retail_Shop

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-" -O vehicle-counting.mp4 && rm -rf /tmp/cookies.txt
# Out:
# --2023-01-24 13:02:04--  https://docs.google.com/uc?export=download&confirm=&id=1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-
# Resolving docs.google.com (docs.google.com)... 74.125.24.138, 74.125.24.101, 74.125.24.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.24.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-ag-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/f4mm17jbtsaotptlfj01po5dbgisis5o/1674565275000/04309230031174164349/*/1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-?e=download&uuid=dab87358-867b-4342-a5c2-165cd9bf3a1f [following]
# Warning: wildcards not supported in HTTP.
# --2023-01-24 13:02:06--  https://doc-0s-ag-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/f4mm17jbtsaotptlfj01po5dbgisis5o/1674565275000/04309230031174164349/*/1pz68D1Gsx80MoPg-_q-IbEdESEmyVLm-?e=download&uuid=dab87358-867b-4342-a5c2-165cd9bf3a1f
# Resolving doc-0s-ag-docs.googleusercontent.com (doc-0s-ag-docs.googleusercontent.com)... 74.125.68.132, 2404:6800:4003:c02::84
# Connecting to doc-0s-ag-docs.googleusercontent.com (doc-0s-ag-docs.googleusercontent.com)|74.125.68.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35345757 (34M) [video/mp4]
# Saving to: ‘vehicle-counting.mp4’
#
# vehicle-counting.mp 100%[===================>]  33.71M  61.5MB/s    in 0.5s
#
# 2023-01-24 13:02:07 (61.5 MB/s) - ‘vehicle-counting.mp4’ saved [35345757/35345757]

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/drive/MyDrive/Projects/Retail_Shop

# %%
SOURCE_VIDEO_PATH = f"{HOME}/shop.mp4"

# %%
# !pip install ultralytics==8.0.10

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.10 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.6/78.2 GB disk)

# %%
# %cd {HOME}
# !git clone https://github.com/ifzhang/ByteTrack.git
# !cd ByteTrack && pip3 install -q -r requirements.txt
# !cd ByteTrack && python3 setup.py -q develop
# !pip install -q cython_bbox
# !pip install -q onemetric

from IPython import display
display.clear_output()


import sys
sys.path.append(f"{HOME}/ByteTrack")


import yolox
print("yolox.__version__:", yolox.__version__)
# Out:
# yolox.__version__: 0.1.0

# %%
from yolox.tracker.byte_tracker import BYTETracker, STrack
from onemetric.cv.utils.iou import box_iou_batch
from dataclasses import dataclass


@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8
    aspect_ratio_thresh: float = 3.0
    min_box_area: float = 1.0
    mot20: bool = False

# %%
# !pip install  supervision==0.1.0


from IPython import display
display.clear_output()


import supervision
print("supervision.__version__:", supervision.__version__)
# Out:
# supervision.__version__: 0.1.0

# %%
# settings
MODEL = "yolov8x.pt"

# %%
from ultralytics import YOLO

model = YOLO(MODEL)
model.fuse()
# Out:
# Fusing...
# YOLOv8x summary: 268 layers, 68200608 parameters, 0 gradients, 257.8 GFLOPs

# %%
# !yolo task=detect mode=predict model=yolov8x.pt conf=0.25 source={SOURCE_VIDEO_PATH}
# Out:
# Ultralytics YOLOv8.0.10 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Fusing...
# YOLOv8x summary: 268 layers, 68200608 parameters, 0 gradients, 257.8 GFLOPs
# video 1/1 (1/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 62.7ms
# video 1/1 (2/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 37.7ms
# video 1/1 (3/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 tv, 2 refrigerators, 37.2ms
# video 1/1 (4/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 36.9ms
# video 1/1 (5/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 37.2ms
# video 1/1 (6/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 35.5ms
# video 1/1 (7/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 36.6ms
# video 1/1 (8/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 35.6ms
# video 1/1 (9/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 35.2ms
# video 1/1 (10/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 2 refrigerators, 34.0ms
# video 1/1 (11/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 34.3ms
# video 1/1 (12/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 34.8ms
# video 1/1 (13/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 35.8ms
# video 1/1 (14/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 36.7ms
# video 1/1 (15/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 37.9ms
# video 1/1 (16/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 36.4ms
# video 1/1 (17/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 34.9ms
# video 1/1 (18/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 33.8ms
# video 1/1 (19/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 34.4ms
# video 1/1 (20/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 35.0ms
# video 1/1 (21/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 35.4ms
# video 1/1 (22/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 37.0ms
# video 1/1 (23/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 35.7ms
# video 1/1 (24/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 35.4ms
# video 1/1 (25/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 35.3ms
# video 1/1 (26/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 34.9ms
# video 1/1 (27/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 34.7ms
# video 1/1 (28/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 35.6ms
# video 1/1 (29/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 36.4ms
# video 1/1 (30/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 36.5ms
# video 1/1 (31/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 35.9ms
# video 1/1 (32/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 34.5ms
# video 1/1 (33/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 34.1ms
# video 1/1 (34/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 35.7ms
# video 1/1 (35/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 36.7ms
# video 1/1 (36/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 36.5ms
# video 1/1 (37/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 36.1ms
# video 1/1 (38/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 35.4ms
# video 1/1 (39/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 34.6ms
# video 1/1 (40/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 34.7ms
# video 1/1 (41/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 2 refrigerators, 36.1ms
# video 1/1 (42/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 1 refrigerator, 36.6ms
# video 1/1 (43/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 2 refrigerators, 35.2ms
# video 1/1 (44/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 2 refrigerators, 34.2ms
# video 1/1 (45/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 35.0ms
# video 1/1 (46/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 36.0ms
# video 1/1 (47/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 39.0ms
# video 1/1 (48/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 36.4ms
# video 1/1 (49/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 37.2ms
# video 1/1 (50/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 34.8ms
# video 1/1 (51/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 34.2ms
# video 1/1 (52/1437) /content/drive/MyDrive/Projects/Retail_Shop/shop.mp4: 352x640 34
# Ultralytics YOLOv8.0.10 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)

# %%
from typing import List

import numpy as np


# converts Detections into format that can be consumed by match_detections_with_tracks function
def detections2boxes(detections: Detections) -> np.ndarray:
    return np.hstack((
        detections.xyxy,
        detections.confidence[:, np.newaxis]
    ))


# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)


# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: Detections, 
    tracks: List[STrack]
) -> Detections:
    detection_boxes = detections.xyxy
    
    tracks_boxes = tracks2boxes(tracks=tracks)
    
    iou = box_iou_batch(tracks_boxes, detection_boxes)
    track2detection = np.argmax(iou, axis=1)
    
    tracker_ids = [None] * len(detections)
    
    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            tracker_ids[detection_index] = tracks[tracker_index].track_id

    return tracker_ids

# %%
# settings
LINE_START = Point(250, 210)
LINE_END = Point(380, 225)

TARGET_VIDEO_PATH = f"{HOME}/test_re.mp4"

# %%
from tqdm.notebook import tqdm


# create BYTETracker instance
byte_tracker = BYTETracker(BYTETrackerArgs())
# create VideoInfo instance
video_info = VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
print(video_info)
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create LineCounter instance
line_counter = LineCounter(start=LINE_START, end=LINE_END)
# create instance of BoxAnnotator and LineCounterAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=4, text_thickness=4, text_scale=2)
line_annotator = LineCounterAnnotator(thickness=4, text_thickness=4, text_scale=2)

# open target video file
with VideoSink(TARGET_VIDEO_PATH, video_info) as sink:
    # loop over video frames
    for frame in tqdm(generator, total=video_info.total_frames):
        # model prediction on single frame and conversion to supervision Detections
        results = model(frame)[0]
        detections = Detections(
            xyxy=results.boxes.xyxy.cpu().numpy(),
            confidence=results.boxes.conf.cpu().numpy(),
            class_id=results.boxes.cls.cpu().numpy().astype(int)
        )
        # filtering out detections with unwanted classes
        mask = np.array([class_id in CLASS_ID for class_id in detections.class_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # tracking detections
        tracks = byte_tracker.update(
            output_results=detections2boxes(detections=detections),
            img_info=frame.shape,
            img_size=frame.shape
        )
        if tracks==[]:
          continue

        
        tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
        
        detections.tracker_id = np.array(tracker_id)
        # filtering out detections without trackers
        mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # format custom labels
        labels = [
            f"#{tracker_id} {CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
            for _, confidence, class_id, tracker_id
            in detections
        ]
        # updating line counter
        line_counter.update(detections=detections)
        # annotate and display frame
        frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)
        line_annotator.annotate(frame=frame, line_counter=line_counter)
        
        sink.write_frame(frame)
# Out:
# VideoInfo(width=640, height=352, fps=30, total_frames=1437)
#   0%|          | 0/1437 [00:00<?, ?it/s]
# Ultralytics YOLOv8.0.10 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-1e739242000f> in <module>
#      20     for frame in tqdm(generator, total=video_info.total_frames):
#      21         # model prediction on single frame and conversion to supervision Detections
# ---> 22         results = model(frame)[0]
#      23         detections = Detections(
#      24             xyxy=results.boxes.xyxy.cpu().numpy(),
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/yolo/engine/model.py in __call__(self, source, stream, verbose, **kwargs)
#      57
#      58     def __call__(self, source=None, stream=False, verbose=False, **kwargs):
# ---> 59         return self.predict(source, stream, verbose, **kwargs)
#      60
#      61     def _new(self, cfg: str, verbose=True):
#
# /usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/yolo/engine/model.py in predict(self, source, stream, verbose, **kwargs)
#     138         else:  # only update args if predictor is already setup
#     139             self.predictor.args = get_config(self.predictor.args, overrides)
# --> 140         return self.predictor(source=source, stream=stream, verbose=verbose)
#     141
#     142     @smart_inference_mode()
#
# /usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/yolo/engine/predictor.py in __call__(self, source, model, verbose, stream)
#     158             return self.stream_inference(source, model, verbose)
#     159         else:
# --> 160             return list(chain(*list(self.stream_inference(source, model, verbose))))  # merge list of Result into one
#     161
#     162     def predict_cli(self):
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/yolo/engine/predictor.py in stream_inference(self, source, model, verbose)
#     194             # Inference
#     195             with self.dt[1]:
# --> 196                 preds = self.model(im, augment=self.args.augment, visualize=visualize)
#     197
#     198             # postprocess
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/nn/autobackend.py in forward(self, im, augment, visualize)
#     252
#     253         if self.pt or self.nn_module:  # PyTorch
# --> 254             y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     255         elif self.jit:  # TorchScript
#     256             y = self.model(im)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/nn/tasks.py in forward(self, x, augment, profile, visualize)
#     193         if augment:
#     194             return self._forward_augment(x)  # augmented inference, None
# --> 195         return self._forward_once(x, profile, visualize)  # single-scale inference, train
#     196
#     197     def _forward_augment(self, x):
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/nn/tasks.py in _forward_once(self, x, profile, visualize)
#      55             if profile:
#      56                 self._profile_one_layer(m, x, dt)
# ---> 57             x = m(x)  # run
#      58             y.append(x if m.i in self.save else None)  # save output
#      59             if visualize:
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/nn/modules.py in forward(self, x)
#     187
#     188     def forward(self, x):
# --> 189         y = list(self.cv1(x).split((self.c, self.c), 1))
#     190         y.extend(m(y[-1]) for m in self.m)
#     191         return self.cv2(torch.cat(y, 1))
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/nn/modules.py in forward_fuse(self, x)
#      36
#      37     def forward_fuse(self, x):
# ---> 38         return self.act(self.conv(x))
#      39
#      40
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
# --> 463         return self._conv_forward(input, self.weight, self.bias)
#     464
#     465 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     457                             weight, bias, self.stride,
#     458                             _pair(0), self.dilation, self.groups)
# --> 459         return F.conv2d(input, weight, bias, self.stride,
#     460                         self.padding, self.dilation, self.groups)
#     461
#
# KeyboardInterrupt:
