# %% [markdown]
# # Data Set
# *Data set reference:
#
# Shankar Setty, Moula Husain, Parisa Beham, Jyothi Gudavalli, Menaka Kandasamy, Radhesyam Vaddi, Vidyagouri Hemadri, J C Karure, Raja Raju, Rajan, Vijay Kumar and C V Jawahar. "Indian Movie Face Database: A Benchmark for Face Recognition Under Wide Variations"
#
# National Conference on Computer Vision, Pattern Recognition, Image Processing and Graphics (NCVPRIPG), 2013.

# %%
# Importing necessary libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder
from tensorflow.python.keras import utils
from keras.models import Sequential
from keras.layers import Dense, Flatten, InputLayer
import keras
import imageio # To read images
from PIL import Image # For image resizing
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# # To load Training dataset

# %%
import zipfile

# Replace 'your_zip_file.zip' with the actual path to your ZIP file
zip_file_path = '/content/drive/MyDrive/Deep_Learning/Project/Age_Group_Prediction/agedetectiontrain.zip'

# Open the ZIP file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # List all files in the ZIP archive
    file_list = zip_ref.namelist()
    print("Files in the ZIP archive:", file_list)

    # Extract all contents to a specified directory
    extraction_path = '/content/drive/MyDrive/Deep_Learning/Project/Age_Group_Prediction/Training_data/'
    zip_ref.extractall(extraction_path)
    print("Contents extracted to:", extraction_path)
# Out:
# Files in the ZIP archive: ['Train/', 'train.csv', 'Train/0.jpg', 'Train/1.jpg', 'Train/100.jpg', 'Train/10000.jpg', 'Train/10001.jpg', 'Train/10004.jpg', 'Train/10007.jpg', 'Train/10008.jpg', 'Train/10009.jpg', 'Train/10011.jpg', 'Train/10013.jpg', 'Train/10015.jpg', 'Train/10016.jpg', 'Train/10017.jpg', 'Train/10018.jpg', 'Train/10019.jpg', 'Train/1002.jpg', 'Train/10021.jpg', 'Train/10023.jpg', 'Train/10025.jpg', 'Train/10026.jpg', 'Train/10027.jpg', 'Train/10028.jpg', 'Train/1003.jpg', 'Train/10030.jpg', 'Train/10031.jpg', 'Train/10034.jpg', 'Train/10035.jpg', 'Train/10036.jpg', 'Train/10038.jpg', 'Train/1004.jpg', 'Train/10040.jpg', 'Train/10041.jpg', 'Train/10043.jpg', 'Train/10045.jpg', 'Train/10046.jpg', 'Train/10047.jpg', 'Train/10048.jpg', 'Train/1005.jpg', 'Train/10050.jpg', 'Train/10051.jpg', 'Train/10053.jpg', 'Train/10055.jpg', 'Train/10056.jpg', 'Train/10057.jpg', 'Train/10058.jpg', 'Train/10059.jpg', 'Train/1006.jpg', 'Train/10061.jpg', 'Train/10062.jpg', 'Train/10063.jpg', 'Train/10065.jpg', 'Train/10067.jpg', 'Train/10068.jpg', 'Train/10069.jpg', 'Train/1007.jpg', 'Train/10070.jpg', 'Train/10071.jpg', 'Train/10073.jpg', 'Train/10076.jpg', 'Train/10078.jpg', 'Train/10079.jpg', 'Train/1008.jpg', 'Train/10080.jpg', 'Train/10081.jpg', 'Train/10082.jpg', 'Train/10084.jpg', 'Train/10085.jpg', 'Train/10086.jpg', 'Train/10087.jpg', 'Train/10088.jpg', 'Train/1009.jpg', 'Train/10091.jpg', 'Train/10092.jpg', 'Train/10093.jpg', 'Train/10095.jpg', 'Train/10096.jpg', 'Train/10097.jpg', 'Train/10098.jpg', 'Train/10099.jpg', 'Train/101.jpg', 'Train/1010.jpg', 'Train/10100.jpg', 'Train/10101.jpg', 'Train/10103.jpg', 'Train/10104.jpg', 'Train/10105.jpg', 'Train/10107.jpg', 'Train/10108.jpg', 'Train/10109.jpg', 'Train/10110.jpg', 'Train/10111.jpg', 'Train/10112.jpg', 'Train/10116.jpg', 'Train/10117.jpg', 'Train/10118.jpg', 'Train/10119.jpg', 'Train/1012.jpg', 'Train/10120.jpg', 'Train/10122.jpg', 'Train/10123.jpg', 'Train/10125.jpg', 'Train/10126.jpg', 'Train/10127.jpg', 'Train/1013.jpg', 'Train/10130.jpg', 'Train/10131.jpg', 'Train/10132.jpg', 'Train/10133.jpg', 'Train/10134.jpg', 'Train/10135.jpg', 'Train/10137.jpg', 'Train/10139.jpg', 'Train/1014.jpg', 'Train/10140.jpg', 'Train/10141.jpg', 'Train/10143.jpg', 'Train/10145.jpg', 'Train/10146.jpg', 'Train/10147.jpg', 'Train/10149.jpg', 'Train/1015.jpg', 'Train/10150.jpg', 'Train/10152.jpg', 'Train/10153.jpg', 'Train/10156.jpg', 'Train/10157.jpg', 'Train/10159.jpg', 'Train/1016.jpg', 'Train/10160.jpg', 'Train/10161.jpg', 'Train/10164.jpg', 'Train/10165.jpg', 'Train/10166.jpg', 'Train/10167.jpg', 'Train/10168.jpg', 'Train/10169.jpg', 'Train/1017.jpg', 'Train/10171.jpg', 'Train/10172.jpg', 'Train/10173.jpg', 'Train/10174.jpg', 'Train/10175.jpg', 'Train/10176.jpg', 'Train/10177.jpg', 'Train/10178.jpg', 'Train/10179.jpg', 'Train/1018.jpg', 'Train/10181.jpg', 'Train/10182.jpg', 'Train/10183.jpg', 'Train/10184.jpg', 'Train/10185.jpg', 'Train/10187.jpg', 'Train/10188.jpg', 'Train/10189.jpg', 'Train/10190.jpg', 'Train/10191.jpg', 'Train/10192.jpg', 'Train/10193.jpg', 'Train/10195.jpg', 'Train/10196.jpg', 'Train/10197.jpg', 'Train/10198.jpg', 'Train/10199.jpg', 'Train/102.jpg', 'Train/1020.jpg', 'Train/10200.jpg', 'Train/10201.jpg', 'Train/10202.jpg', 'Train/10203.jpg', 'Train/10204.jpg', 'Train/10205.jpg', 'Train/10206.jpg', 'Train/10207.jpg', 'Train/10209.jpg', 'Train/1021.jpg', 'Train/10210.jpg', 'Train/10211.jpg', 'Train/10212.jpg', 'Train/10213.jpg', 'Train/10214.jpg', 'Train/10215.jpg', 'Train/10216.jpg', 'Train/10217.jpg', 'Train/10219.jpg', 'Train/1022.jpg', 'Train/10220.jpg', 'Train/10221.jpg', 'Train/10222.jpg', 'Train/10224.jpg', 'Train/10225.jpg', 'Train/10226.jpg', 'Train/10229.jpg', 'Train/10231.jpg', 'Train/10232.jpg', 'Train/10235.jpg', 'Train/10236.jpg', 'Train/10237.jpg', 'Train/10239.jpg', 'Train/10240.jpg', 'Train/10245.jpg', 'Train/10246.jpg', 'Train/10247.jpg', 'Train/10248.jpg', 'Train/1025.jpg', 'Train/10250.jpg', 'Train/10251.jpg', 'Train/10252.jpg', 'Train/10253. ...
# Contents extracted to: /content/drive/MyDrive/Deep_Learning/Project/Age_Group_Prediction/Training_data/

# %% [markdown]
# # To load testing dataset

# %%
import zipfile

# Replace 'your_zip_file.zip' with the actual path to your ZIP file
zip_file_path = '/content/drive/MyDrive/Deep_Learning/Project/Age_Group_Prediction/agedetectiontest.zip'

# Open the ZIP file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # List all files in the ZIP archive
    file_list = zip_ref.namelist()
    print("Files in the ZIP archive:", file_list)

    # Extract all contents to a specified directory
    extraction_path = '/content/drive/MyDrive/Deep_Learning/Project/Age_Group_Prediction/Testing_data/'
    zip_ref.extractall(extraction_path)
    print("Contents extracted to:", extraction_path)
# Out:
# Files in the ZIP archive: ['Test/', 'test.csv', 'Test/10.jpg', 'Test/1000.jpg', 'Test/10002.jpg', 'Test/10003.jpg', 'Test/10005.jpg', 'Test/10006.jpg', 'Test/1001.jpg', 'Test/10010.jpg', 'Test/10012.jpg', 'Test/10014.jpg', 'Test/10020.jpg', 'Test/10022.jpg', 'Test/10024.jpg', 'Test/10029.jpg', 'Test/10032.jpg', 'Test/10033.jpg', 'Test/10037.jpg', 'Test/10039.jpg', 'Test/10042.jpg', 'Test/10044.jpg', 'Test/10049.jpg', 'Test/10052.jpg', 'Test/10054.jpg', 'Test/10060.jpg', 'Test/10064.jpg', 'Test/10066.jpg', 'Test/10072.jpg', 'Test/10074.jpg', 'Test/10075.jpg', 'Test/10077.jpg', 'Test/10083.jpg', 'Test/10089.jpg', 'Test/10090.jpg', 'Test/10094.jpg', 'Test/10102.jpg', 'Test/10106.jpg', 'Test/1011.jpg', 'Test/10113.jpg', 'Test/10114.jpg', 'Test/10115.jpg', 'Test/10121.jpg', 'Test/10124.jpg', 'Test/10128.jpg', 'Test/10129.jpg', 'Test/10136.jpg', 'Test/10138.jpg', 'Test/10142.jpg', 'Test/10144.jpg', 'Test/10148.jpg', 'Test/10151.jpg', 'Test/10154.jpg', 'Test/10155.jpg', 'Test/10158.jpg', 'Test/10162.jpg', 'Test/10163.jpg', 'Test/10170.jpg', 'Test/10180.jpg', 'Test/10186.jpg', 'Test/1019.jpg', 'Test/10194.jpg', 'Test/10208.jpg', 'Test/10218.jpg', 'Test/10223.jpg', 'Test/10227.jpg', 'Test/10228.jpg', 'Test/1023.jpg', 'Test/10230.jpg', 'Test/10233.jpg', 'Test/10234.jpg', 'Test/10238.jpg', 'Test/1024.jpg', 'Test/10241.jpg', 'Test/10242.jpg', 'Test/10243.jpg', 'Test/10244.jpg', 'Test/10249.jpg', 'Test/10254.jpg', 'Test/10256.jpg', 'Test/10265.jpg', 'Test/1027.jpg', 'Test/10274.jpg', 'Test/1028.jpg', 'Test/10288.jpg', 'Test/1029.jpg', 'Test/10290.jpg', 'Test/10292.jpg', 'Test/10295.jpg', 'Test/10297.jpg', 'Test/10298.jpg', 'Test/10304.jpg', 'Test/10306.jpg', 'Test/10307.jpg', 'Test/10312.jpg', 'Test/10314.jpg', 'Test/10322.jpg', 'Test/10329.jpg', 'Test/1033.jpg', 'Test/10332.jpg', 'Test/10337.jpg', 'Test/10339.jpg', 'Test/10340.jpg', 'Test/10347.jpg', 'Test/10349.jpg', 'Test/10350.jpg', 'Test/10353.jpg', 'Test/10354.jpg', 'Test/10356.jpg', 'Test/10358.jpg', 'Test/10364.jpg', 'Test/10367.jpg', 'Test/10369.jpg', 'Test/10370.jpg', 'Test/10380.jpg', 'Test/10382.jpg', 'Test/10384.jpg', 'Test/10391.jpg', 'Test/10392.jpg', 'Test/10394.jpg', 'Test/10397.jpg', 'Test/10399.jpg', 'Test/104.jpg', 'Test/1040.jpg', 'Test/10401.jpg', 'Test/10403.jpg', 'Test/10404.jpg', 'Test/10406.jpg', 'Test/10409.jpg', 'Test/10410.jpg', 'Test/10412.jpg', 'Test/10415.jpg', 'Test/10418.jpg', 'Test/10421.jpg', 'Test/1044.jpg', 'Test/10445.jpg', 'Test/10446.jpg', 'Test/10448.jpg', 'Test/10459.jpg', 'Test/1046.jpg', 'Test/10460.jpg', 'Test/10462.jpg', 'Test/10466.jpg', 'Test/1047.jpg', 'Test/10479.jpg', 'Test/10484.jpg', 'Test/10486.jpg', 'Test/10495.jpg', 'Test/10498.jpg', 'Test/10499.jpg', 'Test/105.jpg', 'Test/10519.jpg', 'Test/1052.jpg', 'Test/10521.jpg', 'Test/10523.jpg', 'Test/10524.jpg', 'Test/10528.jpg', 'Test/10534.jpg', 'Test/10542.jpg', 'Test/10548.jpg', 'Test/10557.jpg', 'Test/10562.jpg', 'Test/10565.jpg', 'Test/10567.jpg', 'Test/10571.jpg', 'Test/10574.jpg', 'Test/10587.jpg', 'Test/10589.jpg', 'Test/10590.jpg', 'Test/10591.jpg', 'Test/10601.jpg', 'Test/10603.jpg', 'Test/10606.jpg', 'Test/10608.jpg', 'Test/10611.jpg', 'Test/10614.jpg', 'Test/10617.jpg', 'Test/10620.jpg', 'Test/10624.jpg', 'Test/10627.jpg', 'Test/1063.jpg', 'Test/10630.jpg', 'Test/10633.jpg', 'Test/10634.jpg', 'Test/10638.jpg', 'Test/10639.jpg', 'Test/10644.jpg', 'Test/10647.jpg', 'Test/10648.jpg', 'Test/10649.jpg', 'Test/10651.jpg', 'Test/10656.jpg', 'Test/10658.jpg', 'Test/10663.jpg', 'Test/10669.jpg', 'Test/10670.jpg', 'Test/10673.jpg', 'Test/10677.jpg', 'Test/10678.jpg', 'Test/10679.jpg', 'Test/10681.jpg', 'Test/10684.jpg', 'Test/10685.jpg', 'Test/10688.jpg', 'Test/10689.jpg', 'Test/10694.jpg', 'Test/10698.jpg', 'Test/10703.jpg', 'Test/10706.jpg', 'Test/10710.jpg', 'Test/10711.jpg', 'Test/10714.jpg', 'Test/10716.jpg', 'Test/1072.jpg', 'Test/10721.jpg', 'Test/10728.jpg', 'Test/10730.jpg', 'Test/10735.jpg', 'Test/10739.jpg', 'Test/10744.jpg', 'Test/10746.jpg', 'Test/10761.jpg', 'Test/10764.jpg' ...
# Contents extracted to: /content/drive/MyDrive/Deep_Learning/Project/Age_Group_Prediction/Testing_data/

# %%
# Reading the data
train = pd.read_csv('/content/drive/MyDrive/Deep_Learning/Project/Age_Group_Prediction/Training_data/train.csv')
test = pd.read_csv('/content/drive/MyDrive/Deep_Learning/Project/Age_Group_Prediction/Testing_data/test.csv')

# %%
train.head()
# Out:
#           ID   Class
# 0    377.jpg  MIDDLE
# 1  17814.jpg   YOUNG
# 2  21283.jpg  MIDDLE
# 3  16496.jpg   YOUNG
# 4   4487.jpg  MIDDLE

# %%
np.random.seed(10)
idx = np.random.choice(train.index)
img_name = train.ID[idx]
img = imageio.imread(os.path.join('/content/drive/MyDrive/Deep_Learning/Project/Age_Group_Prediction/Training_data/Train', img_name))
print('Age group:', train.Class[idx])
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# Age group: MIDDLE
# <ipython-input-56-2baa465edc32>:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(os.path.join('/content/drive/MyDrive/Deep_Learning/Project/Age_Group_Prediction/Training_data/Train', img_name))

# %%
# Image resizing of train data into single numpy array
temp = []
for img_name in train.ID:
    img_path = os.path.join('/content/drive/MyDrive/Deep_Learning/Project/Age_Group_Prediction/Training_data/Train', img_name)
    img = imageio.imread(img_path)
    img = np.array(Image.fromarray(img).resize((32, 32))).astype('float32')
    temp.append(img)
# Out:
# <ipython-input-57-6634f5c7f42e>:5: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(img_path)

# %%
train_x = np.stack(temp)

# %%
# Image resizing of train data into single numpy array
temp = []
for img_name in test.ID:
    img_path = os.path.join('/content/drive/MyDrive/Deep_Learning/Project/Age_Group_Prediction/Testing_data/Test', img_name)
    img = imageio.imread(img_path)
    img = np.array(Image.fromarray(img).resize((32, 32))).astype('float32')
    temp.append(img)
# Out:
# <ipython-input-59-227db32277c0>:5: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(img_path)

# %%
test_x = np.stack(temp)

# %%
# Normalizing the images
train_x = train_x / 255.
test_x = test_x / 255.

# %%
# Encoding the categorical variable to numeric
lb = LabelEncoder()
train_y = lb.fit_transform(train.Class)
train_y = to_categorical(train_y)

# %%
# Specifying all the parameters we will be using in our network
input_num_units = (32, 32, 3)
hidden_num_units = 500
output_num_units = 3
epochs = 5
batch_size = 128

# %%
model = Sequential([
  InputLayer(input_shape=input_num_units),
  Flatten(),
  Dense(units=hidden_num_units, activation='relu'),
  Dense(units=output_num_units, activation='softmax'),
])

# %%
# Printing model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 3072)              0
#
#  dense_2 (Dense)             (None, 500)               1536500
#
#  dense_3 (Dense)             (None, 3)                 1503
#
# =================================================================
# Total params: 1,538,003
# Trainable params: 1,538,003
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling and Training Network
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(train_x, train_y, batch_size=batch_size, epochs=epochs, verbose=1)
# Out:
# Epoch 1/5
# 156/156 [==============================] - 4s 22ms/step - loss: 0.8964 - accuracy: 0.5667
# Epoch 2/5
# 156/156 [==============================] - 4s 23ms/step - loss: 0.8416 - accuracy: 0.6078
# Epoch 3/5
# 156/156 [==============================] - 4s 25ms/step - loss: 0.8287 - accuracy: 0.6101
# Epoch 4/5
# 156/156 [==============================] - 5s 30ms/step - loss: 0.8122 - accuracy: 0.6245
# Epoch 5/5
# 156/156 [==============================] - 3s 21ms/step - loss: 0.8051 - accuracy: 0.6291

# %%
# Training model along with validation data
model.fit(train_x, train_y, batch_size=batch_size, epochs=epochs, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/5
# 125/125 [==============================] - 3s 27ms/step - loss: 0.8015 - accuracy: 0.6309 - val_loss: 0.8235 - val_accuracy: 0.6045
# Epoch 2/5
# 125/125 [==============================] - 5s 40ms/step - loss: 0.7921 - accuracy: 0.6397 - val_loss: 0.7789 - val_accuracy: 0.6482
# Epoch 3/5
# 125/125 [==============================] - 3s 27ms/step - loss: 0.7901 - accuracy: 0.6349 - val_loss: 0.7972 - val_accuracy: 0.6341
# Epoch 4/5
# 125/125 [==============================] - 3s 24ms/step - loss: 0.7819 - accuracy: 0.6475 - val_loss: 0.7768 - val_accuracy: 0.6494
# Epoch 5/5
# 125/125 [==============================] - 3s 24ms/step - loss: 0.7803 - accuracy: 0.6458 - val_loss: 0.7719 - val_accuracy: 0.6524

# %%
# Predicting and importing the result in a csv file
# Assuming you have imported necessary libraries and loaded your model and data

# Predicting probabilities for each class
pred_probs = model.predict(test_x)

# Getting the index of the class with the highest probability for each sample
pred_indices = pred_probs.argmax(axis=-1)

# Converting indices to class labels using the inverse_transform method (assuming lb is your label binarizer)
pred_labels = lb.inverse_transform(pred_indices)

# Adding the predicted class labels to the test DataFrame
test['Class'] = pred_labels

# Saving the DataFrame to a CSV file
test.to_csv('out.csv', index=False)
# Out:
# 208/208 [==============================] - 1s 6ms/step

# %%
idx = 2481
img_name = test.ID[idx]
img = imageio.imread(os.path.join('/content/drive/MyDrive/Deep_Learning/Project/Age_Group_Prediction/Testing_data/Test', img_name))
plt.imshow(np.array(Image.fromarray(img).resize((128, 128))))

# Get the predicted probabilities for the specific image
pred_probs = model.predict(np.expand_dims(test_x[idx], axis=0))

# Get the index of the predicted class with the highest probability
pred_index = pred_probs.argmax(axis=-1)[0]

# Get the corresponding class label from the label binarizer
pred_label = lb.classes_[pred_index]

print('Original:', test.Class[idx], 'Predicted:', pred_label)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# <ipython-input-70-47432cedef5f>:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(os.path.join('/content/drive/MyDrive/Deep_Learning/Project/Age_Group_Prediction/Testing_data/Test', img_name))
# Original: MIDDLE Predicted: MIDDLE
