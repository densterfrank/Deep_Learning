# %%
# !nvidia-smi
# Out:
# Sun Jan 29 01:46:22 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8    13W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = '/content/drive/MyDrive/Telemus/Drowsiness'
print(HOME)
# Out:
# /content/drive/MyDrive/Telemus/Drowsiness

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.7/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="PmWJhSzHtKm0icwOJGne")
project = rf.workspace("augmented-startups").project("drowsiness-detection-cntmz")
dataset = project.version(2).download("yolov8")
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/Telemus/Drowsiness/datasets’: File exists
# /content/drive/MyDrive/Telemus/Drowsiness/datasets
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Drowsiness-Detection-2 in yolov8:: 100%|██████████| 2472/2472 [21:28<00:00,  1.92it/s]

# %%
cd {HOME}
# Out:
# /content/drive/MyDrive/Telemus/Drowsiness

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/Telemus/Drowsiness/datasets/Drowsiness-Detection-2/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source='/content/drive/MyDrive/Telemus/Drowsiness/datasets/clip_2.mp4' save=True
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# video 1/1 (1/511) /content/drive/MyDrive/Telemus/Drowsiness/datasets/clip_2.mp4: 480x800 17.1ms
# video 1/1 (2/511) /content/drive/MyDrive/Telemus/Drowsiness/datasets/clip_2.mp4: 480x800 16.4ms
# video 1/1 (3/511) /content/drive/MyDrive/Telemus/Drowsiness/datasets/clip_2.mp4: 480x800 16.3ms
# video 1/1 (4/511) /content/drive/MyDrive/Telemus/Drowsiness/datasets/clip_2.mp4: 480x800 16.3ms
# video 1/1 (5/511) /content/drive/MyDrive/Telemus/Drowsiness/datasets/clip_2.mp4: 480x800 16.3ms
# video 1/1 (6/511) /content/drive/MyDrive/Telemus/Drowsiness/datasets/clip_2.mp4: 480x800 16.3ms
# video 1/1 (7/511) /content/drive/MyDrive/Telemus/Drowsiness/datasets/clip_2.mp4: 480x800 16.3ms
# video 1/1 (8/511) /content/drive/MyDrive/Telemus/Drowsiness/datasets/clip_2.mp4: 480x800 16.3ms
# ...

# %%
model={HOME}/runs/detect/train/weights/best.pt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a7009868d384> in <module>
# ----> 1 model={HOME}/runs/detect/train/weights/best.pt
#
# NameError: name 'runs' is not defined
